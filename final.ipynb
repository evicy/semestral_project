# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from Functions import read_histo_from_file
        
# Zadaj subor .txt (jellyfish histo genomicke informacie) 

#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\ecoli_k_11.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\ecoli_k_21.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\ecoli_k_31.txt')

#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\AraTha_k_11.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\AraTha_k_21.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\AraTha_k_31.txt')

#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\kvasinka_k_11.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\kvasinka_k_21.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\kvasinka_k_31.txt')

#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\DroMel_k_11.txt')
histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\DroMel_k_21.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\DroMel_k_31.txt')

#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\staphylococ_k_11.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\staphylococ_k_21.txt')
#histo = read_histo_from_file('C:\\Users\\Evi\\Documents\\Data\\staphylococ_k_31.txt')

# %%
from DrawDistributions import draw

# Zadaj limitu pre os x>
max_x=40

# Zadaj pocet shiftnuti
num_of_shifts = 4

data = draw(histo, max_x, num_of_shifts)
# Out:
# Top 3 for L1 norm:
# Cauchy , shifted:  3
# Cauchy , shifted:  2
# Pareto , shifted:  3
#
# Top 3 for L2 norm:
# Cauchy , shifted:  2
# Cauchy , shifted:  3
# Pareto , shifted:  3

# %%
from DrawErrors import drawErrors

drawErrors(data)
